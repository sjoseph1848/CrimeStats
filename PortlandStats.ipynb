# %%
import csv
# %precision 2

with open('crime_incident_data2004.csv') as csvfile:
    crime04 = list(csv.DictReader(csvfile))

# %%
import pandas as pd 
crime04 = pd.read_csv('crime_incident_data2004.csv')
print(crime04.head())
# Out:
#    Record ID Report Date Report Time   Major Offense Type  \
# 0   10711678  03/02/2004    11:09:00              Larceny
# 1   10704487  02/11/2004    09:18:00  Motor Vehicle Theft
# 2   10796264  10/27/2004    22:19:00              Larceny
# 3   10744595  06/08/2004    12:06:00      Assault, Simple
# 4   10803413  11/16/2004    17:00:00   Disorderly Conduct
#
#                                              Address    Neighborhood  \
# 0  NE HOLLADAY ST and NE 1ST AVE, PORTLAND, OR 97232           LLOYD
# 1   NE WEIDLER ST and NE 1ST AVE, PORTLAND, OR 97232           LLOYD
# 2  NE SCHUYLER ST and NE 1ST AVE, PORTLAND, OR 97212           ELIOT
# 3    101-199 block of NW 1ST AVE, PORTLAND, OR 97209  CHINA/OLD TOWN
# 4    101-199 block of NW 1ST AVE, PORTLAND, OR 97209  CHINA/OLD TOWN
#
#     Police Precinct Police District  X Coordinate  Y Coordinate
# 0  PORTLAND PREC NO             690  7.647409e+06  686790.02595
# 1  PORTLAND PREC NO             690  7.647471e+06  688344.45000
# ...

# %%
crime04.shape
# Out:
# (82958, 10)

# %%
Lloyd = crime04['Neighborhood'] == 'LLOYD'

# %%
crime04[Lloyd]
# Out:
#        Record ID Report Date Report Time   Major Offense Type  \
# 0       10711678  03/02/2004    11:09:00              Larceny
# 1       10704487  02/11/2004    09:18:00  Motor Vehicle Theft
# 164     10800068  11/05/2004    18:24:00                 DUII
# 360     10805725  11/23/2004    23:31:00  Motor Vehicle Theft
# 361     10709106  02/23/2004    08:50:00          Liquor Laws
# 362     10749063  06/21/2004    15:30:00  Motor Vehicle Theft
# 363     10797605  10/31/2004    19:09:00              Robbery
# 1604    10765078  08/05/2004    19:41:00  Motor Vehicle Theft
# 1605    10700862  01/29/2004    15:56:00              Larceny
# 1606    10779756  09/12/2004    17:28:00              Larceny
# 1607    10789488  10/09/2004    12:56:00             Trespass
# 1608    10738069  05/18/2004    17:00:00              Larceny
# 1609    10794159  10/21/2004    17:27:00              Larceny
# 2030    10778597  09/09/2004    15:58:00              Forgery
# ...
